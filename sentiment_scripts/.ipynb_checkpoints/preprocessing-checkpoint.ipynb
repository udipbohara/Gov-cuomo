# %%
import json
import pandas as pd
import warnings
import matplotlib.pyplot as plt 
warnings.filterwarnings('ignore')

# %%
import glob
import pandas as pd

files = glob.glob('../data/feb/*.json')
dfs = [pd.read_json(f) for f in files]
df_april = pd.concat(dfs,ignore_index=True)

# %%
df_april.columns
# Out:
# Index(['has_media', 'hashtags', 'img_urls', 'is_replied', 'is_reply_to',
#        'likes', 'links', 'parent_tweet_id', 'replies', 'reply_to_users',
#        'retweets', 'screen_name', 'text', 'text_html', 'timestamp',
#        'timestamp_epochs', 'tweet_id', 'tweet_url', 'user_id', 'username',
#        'video_url'],
#       dtype='object')

# %%
df_march = df_april.copy()

# %%
df_march.timestamp
# Out:
# 0      2020-02-29 23:12:05
# 1      2020-02-29 23:08:34
# 2      2020-02-29 22:49:35
# 3      2020-02-29 22:33:33
# 4      2020-02-29 21:35:47
# 5      2020-02-29 21:25:18
# 6      2020-02-29 21:18:33
# 7      2020-02-29 20:58:37
# 8      2020-02-29 20:57:29
# 9      2020-02-29 20:48:08
# 10     2020-02-29 20:48:08
# 11     2020-02-29 20:48:08
# 12     2020-02-29 20:20:00
# 13     2020-02-29 19:50:00
# 14     2020-02-29 19:49:54
# 15     2020-02-29 19:17:49
# 16     2020-02-29 18:59:45
# 17     2020-02-29 18:59:26
# 18     2020-02-29 18:54:13
# 19     2020-02-29 18:52:39
# 20     2020-02-29 23:12:05
# 21     2020-02-29 23:08:34
# 22     2020-02-29 22:49:35
# 23     2020-02-29 22:33:33
# 24     2020-02-29 21:35:47
# 25     2020-02-29 21:25:18
# 26     2020-02-29 21:18:33
# 27     2020-02-29 20:58:37
# 28     2020-02-29 20:57:29
# 29     2020-02-29 20:48:08
#                ...
# 4598   2020-02-01 02:56:47
# 4599   2020-02-01 02:56:41
# 4600   2020-02-01 02:55:18
# 4601   2020-02-01 02:54:29
# 4602   2020-02-01 02:47:32
# 4603   2020-02-01 02:41:57
# 4604   2020-02-01 02:38:33
# 4605   2020-02-01 02:36:05
# 4606   2020-02-01 02:26:44
# 4607   2020-02-01 02:24:26
# 4608   2020-02-01 02:19:24
# 4609   2020-02-01 02:16:47
# 4610   2020-02-01 02:12:25
# 4611   2020-02-01 02:11:06
# 4612   2020-02-01 02:08:38
# 4613   2020-02-01 02:06:48
# 4614   2020-02-01 01:58:33
# 4615   2020-02-01 01:41:42
# 4616   2020-02-01 01:38:52
# 4617   2020-02-01 01:19:28
# 4618   2020-02-01 01:18:33
# 4619   2020-02-01 01:07:04
# 4620   2020-02-01 00:59:42
# 4621   2020-02-01 00:56:31
# 4622   2020-02-01 00:51:24
# 4623   2020-02-01 00:47:00
# 4624   2020-02-01 00:35:49
# 4625   2020-02-01 00:28:34
# 4626   2020-02-01 00:22:36
# 4627   2020-02-01 00:22:14
# Name: timestamp, Length: 4628, dtype: datetime64[ns]

# %%
len(df_march)
# Out:
# 4628

# %%
df_march = df_march.sort_values(['timestamp'])

# %%
df_march.isna().sum()
# Out:
# has_media           0
# hashtags            0
# img_urls            0
# is_replied          0
# is_reply_to         0
# likes               0
# links               0
# parent_tweet_id     0
# replies             0
# reply_to_users      0
# retweets            0
# screen_name         0
# text                0
# text_html           0
# timestamp           0
# timestamp_epochs    0
# tweet_id            0
# tweet_url           0
# user_id             0
# username            0
# video_url           0
# dtype: int64

# %%
df_march.user_id = df_march.user_id.astype(str)
df_march.tweet_id = df_march.tweet_id.astype(str)

df_march.drop_duplicates('tweet_id', inplace=True)
#Filtering tweets of Gov Cuomo by his user ID.
march_cuomo = df_march.loc[df_march.user_id ==  '232268199']

#remove all tweets from Gov Cuomo and drop duplicates for tweets.
march_all = df_march.loc[df_march.user_id !='232268199']

# %%
len(march_all)
# Out:
# 4576

# %% [markdown]
# __Data Cleaning, Text cleaning__

# %%
contraction_map = {
"ain't": "is not","aren't": "are not","can't": "cannot","can't've": "cannot have","'cause": "because",
"could've": "could have","couldn't": "could not","couldn't've": "could not have","didn't": "did not",
"doesn't": "does not","don't": "do not","hadn't": "had not","hadn't've": "had not have","hasn't": "has not",
"haven't": "have not","he'd": "he would","he'd've": "he would have","he'll": "he will","he'll've": "he he will have","he's": "he is",
"how'd": "how did","how'd'y": "how do you","how'll": "how will","how's": "how is","I'd": "I would","I'd've": "I would have",
"I'll": "I will","I'll've": "I will have","I'm": "I am","I've": "I have","i'd": "i would","i'd've": "i would have","i'll": "i will",
"i'll've": "i will have","i'm": "i am","i've": "i have","isn't": "is not","it'd": "it would","it'd've": "it would have","it'll": "it will",
"it'll've": "it will have","it's": "it is","let's": "let us","ma'am": "madam","mayn't": "may not",
"might've": "might have","mightn't": "might not","mightn't've": "might not have","must've": "must have","mustn't": "must not",
"mustn't've": "must not have","needn't": "need not","needn't've": "need not have","o'clock": "of the clock",
"oughtn't": "ought not","oughtn't've": "ought not have","shan't": "shall not","sha'n't": "shall not","shan't've": "shall not have",
"she'd": "she would","she'd've": "she would have","she'll": "she will","she'll've": "she will have",
"she's": "she is","should've": "should have","shouldn't": "should not","shouldn't've": "should not have","so've": "so have",
"so's": "so as","that'd": "that would","that'd've": "that would have","that's": "that is",
"there'd": "there would","there'd've": "there would have","there's": "there is","they'd": "they would","they'd've": "they would have","they'll": "they will","they'll've": "they will have",
"they're": "they are","they've": "they have","to've": "to have","wasn't": "was not",
"we'd": "we would","we'd've": "we would have","we'll": "we will","we'll've": "we will have","we're": "we are","we've": "we have",
"weren't": "were not","what'll": "what will","what'll've": "what will have","what're": "what are",
"what's": "what is","what've": "what have","when's": "when is","when've": "when have","where'd": "where did","where's": "where is",
"where've": "where have","who'll": "who will","who'll've": "who will have","who's": "who is","who've": "who have",
"why's": "why is","why've": "why have","will've": "will have","won't": "will not","won't've": "will not have","would've": "would have",
"wouldn't": "would not","wouldn't've": "would not have","y'all": "you all","y'all'd": "you all would","y'all'd've": "you all would have",
"y'all're": "you all are","y'all've": "you all have","you'd": "you would","you'd've": "you would have","you'll": "you will",
"you'll've": "you will have","you're": "you are","you've": "you have"
}

# %%
import re 
import unicodedata

def remove_special_chars(text, remove_digits=False):
    pattern = r'[^a-zA-z0-9\s]' if not remove_digits else r'[^a-zA-z\s]'
    text = re.sub(pattern, '', text)
    return text

def remove_accented_chars(text):
    text = unicodedata.normalize('NFKD', text).encode('ascii', 'ignore').decode('utf-8', 'ignore')
    return text

def remove_url_chars(text):
    text = re.sub("([^0-9A-Za-z \t])|(\w+:\/\/\S+)", "", text)
    return text 

def expand_contractions(text, contraction_mapping=contraction_map):

    contractions_pattern = re.compile('({})'.format('|'.join(contraction_mapping.keys())), 
                                      flags=re.IGNORECASE|re.DOTALL)
    def expand_match(contraction):
        match = contraction.group(0)
        first_char = match[0]
        expanded_contraction = contraction_mapping.get(match)\
                                if contraction_mapping.get(match)\
                                else contraction_mapping.get(match.lower())                       
        expanded_contraction = first_char+expanded_contraction[1:]
        return expanded_contraction

    expanded_text = contractions_pattern.sub(expand_match, text)
    expanded_text = re.sub("'", "", expanded_text)
    return expanded_text

# %%
#create dictionary of the functions to be applied
funcdict = {"1": expand_contractions,"2": remove_special_chars, "3": remove_accented_chars}

#apply the functions in a loop
march_all['processed_text'] = march_all.text

for k,v in funcdict.items():
    march_all.processed_text = march_all.processed_text.apply(lambda x: v(x))

#remove new line chars and lowercase the letters.
march_all.processed_text = march_all.processed_text.replace('\n','', regex=True).str.lower()

# %%
march_all.processed_text
# Out:
# 4627    wtf newyorkcity guess where we are not going f...
# 4626    seriously billdeblasio and nygovcuomo get your...
# 4625    bellamy music leopard print  god is dead rats ...
# 4624    cuomo is in charge of mta mta is a mess cuomo ...
# 4623    anyone hear from nycmayor nygovcuomo about the...
# 4622    i am so happy to see so many people scolding d...
# 4621                     rivers cuomo is a hero to us all
# 4620    if i was the mayor of new york i would give th...
# 4619    great job nycmayor nygovcuomo you have single ...
# 4618    new album hendrix dead inside oasis is gay i l...
# 4617    why would cuomo implement bail reform and why ...
# 4616    husband just showed me photo of what ia happen...
# 4615    where is new yorks leadership  respect the pol...
# 4614    never hendrix leopard print pee uhhhhhhhh mons...
# 4613    cuomo on tv telling people  trumpacquitted  th...
# 4612    cuomo cuimoprimetime i think you guys are maki...
# 4611    i cant with cuomo and his nicknames and talk s...
# 4610    a bunch of defeated and deflated democrats liv...
# 4609    cnn cuomo  contributors are upset of the vote ...
# 4608    tester speaking gospel on cuomo gopcowards gop...
# 4607    these fthepolice protest has been a mess for c...
# 4606    cuomo looks so pitiful trying to make light of...
# 4605    head to head on cuomo tonight between mccabe a...
# 4604    never rayana gay pee  mucore die antwoord am w...
# 4603    current mood rivers cuomo singing im tired so ...
# 4602    its pretty clear that given the potential 2020...
# 4601    left is going nuts  pathetic jerks who overloo...
# 4600    cuomo rubio said of trumphe is a conman who sh...
# 4599    on days like thisi watch cnn fredo cuomo is ha...
# 4598    crock of cuomo imploring americans to be mad a...
#                               ...
# 49      new york state won us approval to conduct its ...
# 48      world courage riseup america and change is com...
# 47      isles activated cal clutterbuck off ir while g...
# 46      recommendation from 911 experience this is lif...
# 45      wayne lapierre  nra preswhat we saw in ca is n...
# 44      fuck nygovcuomo  nycmayor cant wait for nyc to...
# 43      cuomo and lemon  the giggles boys act like sil...
# 42      wayne lapierre  nra prescuomo knows if we cann...
# 41      wayne lapierre has been ranting about how the ...
# 40      wayne lapierre  nra pres nra is suing cuomo an...
# 19      just went shopping aldiusa  thank god emperor ...
# 18      im finding it difficult to believe any normal ...
# 17      nygovcuomo says feds have okayed request to le...
# 36      new york governor andrew cuomo did not know ho...
# 35      andrew cuomo and bill de blasio are taking cre...
# 14      the fda announced today that nys and other loc...
# 13          can we get cuomo the hell outta office please
# 32      metropolitanbound m trains have resumed becaus...
# 9       carleheastie paidsickdays are fundamental to t...
# 10      nygovcuomo paidsickdays are fundamental to the...
# 11      andreascousins paidsickdays are fundamental to...
# 8       oh now im majorly pissed the fuck off nygovcuo...
# 7       is mary t discriminating against the current d...
# 6       roses are red i can see this is my peepee dog ...
# 25      i miss you train daddyafter sitting idle at 14...
# 24      breaking nygovcuomo responds to unhinged rant ...
# 23      don trump jr threat by garamendi  yet another ...
# 22      thanks to nygovcuomo  so many new yorkers are ...
# 21      never animal print elle  kanye west please sna...
# 20      cuomos wife a bonefide trump hater cannot expl...
# Name: processed_text, Length: 4576, dtype: object

# %%
march_all[march_all.processed_text.str.contains("mario") &
         ~march_all.processed_text.str.contains("andrew")].values
# Out:
# array([[False, list([]), list([]), ..., 'casey gordon', '',
#         'whoever changed the tappan zee bridge name to governor mario cuomo bridge is a fuck'],
#        [False, list([]), list([]), ..., 'William (Bill) Bryson', '',
#         'every time i have done something that does not feel right it is ended up not being right  mario cuomo'],
#        [False, list([]), list([]), ..., 'Matter That Matters', '',
#         'me said enough of your evil stop eating meat and fish and killing our wildlife and that goes for pfiller up go to hell south street blue hens blue buffalo new york malto mario cuomo before pal falls on a driveway generalfoods traderjoesrants pets need beyond meat too'],
#        ...,
#        [False, list(['I87NYSThruway']), list([]), ..., '511NYMidHudson',
#         '',
#         'cleared construction on i87nysthruway nb from governor mario m cuomo bridge to before exit 10 i87  south nyack us 9w'],
#        [False, list([]), list([]), ..., 'Hermit Huw Stan Bob', '',
#         'my mom the life long democratic organizer friend of the late mario cuomo and the most ardent antitrumper in alabama told me today that if it is the president against the socialist she will not vote at all my brain exploded'],
#        [False, list([]), list([]), ..., 'RW Clark Espionage Author', '',
#         'david robinson chose to stay at navy he talked about commitment loyalty and values i wonder how many of us would choose these virtues rather than the chance of becoming a millionaire especially if you were a college sophomore when you had to make that choice  mario cuomo']],
#       dtype=object)

# %%
text = " ".join(_ for _ in march_all.processed_text)

# %%
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator


wc = WordCloud(background_color="white", stopwords=STOPWORDS, max_words=200, width=400, height=400,  
               random_state=1).generate(text)
plt.figure(figsize=(20,10))
plt.imshow(wc)
plt.axis("off")
plt.show()

# %%
stop_words
# Out:
# ['andrew',
#  'cuomo',
#  'gov',
#  'andrew cuomo',
#  'the',
#  'i',
#  'like',
#  'further',
#  'myself',
#  'this',
#  "he'd",
#  'of',
#  "she's",
#  'been',
#  'ought',
#  'are',
#  'these',
#  'own',
#  "shouldn't",
#  'can',
#  'with',
#  'until',
#  'him',
#  "don't",
#  'if',
#  "you'll",
#  'they',
#  'such',
#  'shall',
#  'few',
#  'but',
#  "here's",
#  'else',
#  "let's",
#  'than',
#  "isn't",
#  'get',
#  "that's",
#  'again',
#  "i'd",
#  'is',
#  'on',
#  'those',
#  'about',
#  'while',
#  'your',
#  "when's",
#  'was',
#  "weren't",
#  'it',
#  'before',
#  "mustn't",
#  'r',
#  "we've",
#  'because',
#  "he'll",
#  'ever',
#  "won't",
#  'hence',
#  'she',
#  'their',
#  'only',
#  'over',
#  'me',
#  'against',
#  'did',
#  'out',
#  'cannot',
#  "doesn't",
#  'were',
#  'that',
#  'them',
#  'by',
#  'whom',
#  'each',
#  'yourself',
#  'my',
#  'you',
#  "hadn't",
#  'have',
#  "shan't",
#  'then',
#  'too',
#  'its',
#  'no',
#  'below',
#  'doing',
#  'between',
#  'do',
#  'nor',
#  'which',
#  'am',
#  'an',
#  "they'd",
#  'as',
#  'itself',
#  'we',
#  'most',
#  'hers',
#  "she'd",
#  "she'll",
#  'from',
#  'themselves',
#  'how',
#  "we're",
#  'however',
#  'to',
#  'up',
#  "hasn't",
#  "who's",
#  'himself',
#  'same',
#  "wouldn't",
#  'any',
#  "couldn't",
#  'a',
#  'and',
#  'he',
#  'our',
#  'both',
#  'very',
#  'does',
#  "he's",
#  'ours',
#  'has',
#  "i've",
#  'what',
#  "i'll",
#  'where',
#  'yourselves',
#  'for',
#  "wasn't",
#  'during',
#  'or',
#  'herself',
#  'off',
#  'should',
#  'k',
#  'there',
#  'through',
#  'yours',
#  "you've",
#  'had',
#  "we'd",
#  "why's",
#  'otherwise',
#  "aren't",
#  'under',
#  "haven't",
#  'being',
#  'into',
#  "there's",
#  'down',
#  'just',
#  'at',
#  'some',
#  "it's",
#  "where's",
#  'would',
#  'once',
#  'why',
#  "you're",
#  "can't",
#  'more',
#  "we'll",
#  'having',
#  'here',
#  'after',
#  "how's",
#  'could',
#  'above',
#  'com',
#  'who',
#  'all',
#  'http',
#  'since',
#  'not',
#  "you'd",
#  "i'm",
#  'therefore',
#  'when',
#  'also',
#  'so',
#  'theirs',
#  'www',
#  'in',
#  "they've",
#  'be',
#  'her',
#  'ourselves',
#  "they'll",
#  'other',
#  "they're",
#  "what's",
#  "didn't",
#  'his']

# %%
stop_words = ['andrew', 'cuomo','gov', 'andrew cuomo'] + list(STOPWORDS)
wc = WordCloud(background_color="white", stopwords=STOPWORDS, max_words=200, width=400, height=400,  
               random_state=1).generate(text)
plt.figure(figsize=(20,10))
plt.imshow(wc)
plt.axis("off")
plt.show()

# %%
from collections import Counter
stopwords = STOPWORDS
#Getting the most common words

filtered_words = [word for word in text.split() if word not in stopwords]
counted_words = Counter(filtered_words)

words = []
counts = []
for letter, count in counted_words.most_common(10):
    words.append(letter)
    counts.append(count)

# %%
march_all.to_pickle("feb_txt_cleaned.pkl")
