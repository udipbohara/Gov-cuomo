# %%
import json
import pandas as pd
import warnings
import matplotlib.pyplot as plt 
warnings.filterwarnings('ignore')

# %%
df = pd.read_pickle("march_trained.pkl")

# %%
from flair.models import TextClassifier
from flair.data import Sentence

tagger = TextClassifier.load('sentiment')

sentence = Sentence('Cuomo is doing the best he can!')

tagger.predict(sentence)

print(sentence.labels)
# Out:
# 2020-05-29 21:45:26,824 loading file /Users/udipbohara/.flair/models/sentiment-en-mix-distillbert.pt
# I0529 21:45:27.139060 4475493824 configuration_utils.py:285] loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/distilbert-base-uncased-config.json from cache at /Users/udipbohara/.cache/torch/transformers/a41e817d5c0743e29e86ff85edc8c257e61bc8d88e4271bb1b243b6e7614c633.8949e27aafafa845a18d98a0e3a88bc2d248bbc32a1b75947366664658f23b1c
# I0529 21:45:27.140494 4475493824 configuration_utils.py:321] Model config DistilBertConfig {
#   "activation": "gelu",
#   "architectures": [
#     "DistilBertForMaskedLM"
#   ],
#   "attention_dropout": 0.1,
#   "dim": 768,
#   "dropout": 0.1,
#   "hidden_dim": 3072,
#   "initializer_range": 0.02,
#   "max_position_embeddings": 512,
#   "model_type": "distilbert",
#   "n_heads": 12,
#   "n_layers": 6,
#   "pad_token_id": 0,
#   "qa_dropout": 0.1,
#   "seq_classif_dropout": 0.2,
#   "sinusoidal_pos_embds": false,
# ...

# %%
sentence.labels[0]
# Out:
# POSITIVE (0.9997)

# %%
sample_df = df[:20]

# %%
value = []
score = []
sentiments = []
for texts in df.processed_text:
    sentence = Sentence(texts)
    tagger.predict(sentence)
    value.append(sentence.labels[0].value)
    score.append(sentence.labels[0].score)
    sentiments.append(sentence.labels)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-118-438f422d493e> in <module>
#       4 for texts in df.processed_text:
#       5     sentence = Sentence(texts)
# ----> 6     tagger.predict(sentence)
#       7     value.append(sentence.labels[0].value)
#       8     score.append(sentence.labels[0].score)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/flair/models/text_classification_model.py in predict(self, sentences, mini_batch_size, embedding_storage_mode, multi_class_prob, verbose, use_tokenizer)
#     229                     continue
#     230
# --> 231                 scores = self.forward(batch)
#     232                 predicted_labels = self._obtain_labels(
#     233                     scores, predict_prob=multi_class_prob
#
# ...

# %%
df['sentiment_value'] = value
df['score'] = score 
df['sentiments'] = sentiments

# %%
df.to_pickle('march_trained.pkl')

# %%
df.sentiment_value.value_counts()
# Out:
# NEGATIVE    60398
# POSITIVE    42847
# Name: sentiment_value, dtype: int64

# %%
sentence.labels[0].value
sentence.labels[0].score
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-84-3ce24df8e471> in <module>
# ----> 1 sentence.labels.value
#       2 sentence.labels[0].score
#
# AttributeError: 'list' object has no attribute 'value'

# %%
sample_df.processed_text.values
# Out:
# array(['gay leaders cried betrayal when new york governor mario cuomo watered down his long awaited executive order banning antigay discrimination november 1983',
#        'fuck you nygovcuomo',
#        'new album i have a girlfriend drums pee  please die antwoord dick weezer blue album more like critically acclaimed cuomo art gallagher what the heck is museslahs',
#        'new album homosexual leopard print pee  mucore shut up matt stop weezer blue album more like critically acclaimed cuomo art lynch the gallaghers',
#        'list of childhood crushes extremely revealingvegas elvisjoey ramonerivers cuomo blue album',
#        'wondering how much ny has lost so far in cashless tollsnygovcuomo',
#        'never music gay fashion  please rats everywhere you look i weezer blue album more like critically acclaimed cuomo art albarn ate my best friend',
# ...

# %%
sample_df[sample_df.processed_text.str.contains("mario m cuomo") &
         ~sample_df.processed_text.str.contains("cow")]
# Out:
#        has_media                hashtags img_urls  is_replied  is_reply_to  \
# 89754      False  [I95NewEnglandThruway]       []       False        False
# 89753      False  [I95NewEnglandThruway]       []       False        False
#
#        likes links parent_tweet_id  replies reply_to_users  ...  \
# 89754      0    []                        0             []  ...
# 89753      0    []                        0             []  ...
#
#                                                     text  \
# 89754  Cleared: Incident on #I95NewEnglandThruway NB ...
# 89753  Cleared: Incident on #I95NewEnglandThruway NB ...
#
#                                                text_html           timestamp  \
# 89754  <p class="TweetTextSize js-tweet-text tweet-te... 2020-03-01 03:59:10
# 89753  <p class="TweetTextSize js-tweet-text tweet-te... 2020-03-01 03:59:10
#
#          timestamp_epochs             tweet_id  \
# 89754 2020-03-01 03:59:10  1233964974260748288
# ...

# %%
df = pd.read_pickle("march_trained.pkl")

# %%
df.sentiment_value.value_counts()
# Out:
# NEGATIVE    60398
# POSITIVE    42847
# Name: sentiment_value, dtype: int64

# %%
#converting all the negative sentiments to '-'ve 
df.loc[df.sentiment_value == 'NEGATIVE', 'score'] = -1 * df.score

# %%
#for above 0.8 threshold for negativity
df.loc[df.score <= -0.8, 'polarity'] = -1 

#for positive polarity threshold
df.loc[df.score >= 0.8, 'polarity'] = 1 

#rest are neutral, polarity = 0 
df['polarity'] = df['polarity'].fillna(0)

# %%
df.polarity.value_counts()
# Out:
# -1.0    52600
#  1.0    35130
#  0.0    15515
# Name: polarity, dtype: int64

# %%
df.columns
# Out:
# Index(['has_media', 'hashtags', 'img_urls', 'is_replied', 'is_reply_to',
#        'likes', 'links', 'parent_tweet_id', 'replies', 'reply_to_users',
#        'retweets', 'screen_name', 'text', 'text_html', 'timestamp',
#        'timestamp_epochs', 'tweet_id', 'tweet_url', 'user_id', 'username',
#        'video_url', 'processed_text', 'sentiment_value', 'score', 'sentiments',
#        'polarity'],
#       dtype='object')

# %% [markdown]
# __Time-Series Graphing__

# %%
# Clean and transform data to enable time series
result_by_month = df.groupby(                                        \
      [pd.Grouper(key='timestamp', freq='D'), 'polarity']).size().rename('count').reset_index()

# %%
#to avoid plots not showing up
import plotly.io as pio
pio.renderers.default='notebook'

# %%
import plotly.express as px
fig = px.line(result, x='timestamp',y="count",color='polarity',
             title='Polarity Counts by Day')

fig.update_layout(shapes=[
    dict(
      type= 'line',
      yref= 'paper', y0= 0, y1= 1,
      xref= 'x', x0= '2020-03-28', x1= '2020-03-28'
    ), 
    dict(
      type= 'line',
      yref= 'paper', y0= 0, y1= 1,
      xref= 'x', x0= '2020-03-18', x1= '2020-03-18'
    )
])

fig.show()
# Out:
# <div>
#
#
#             <div id="54c9a98a-d297-4105-ac2e-e117568253ac" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("54c9a98a-d297-4105-ac2e-e117568253ac")) {
#                     Plotly.newPlot(
#                         '54c9a98a-d297-4105-ac2e-e117568253ac',
# ...

# %%
px.line?

# %%
# Clean and transform data to enable time series
result_by_hour = df.groupby(                                        \
      [pd.Grouper(key='timestamp', freq='H'), 'polarity']).size().rename('count').reset_index()

# %%
import plotly.express as px
fig = px.line(result_by_hour, x='timestamp',y="count",color='polarity',
             title='Polarity Counts by hour')
fig.show()
# Out:
# <div>
#
#
#             <div id="4284dca7-2ab4-4be8-b7f4-18a717394c86" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("4284dca7-2ab4-4be8-b7f4-18a717394c86")) {
#                     Plotly.newPlot(
#                         '4284dca7-2ab4-4be8-b7f4-18a717394c86',
# ...

# %%
daily_counts = pd.read_csv('../data/daily_counts.csv')

# %%
daily_counts['DATE_OF_INTEREST'] = pd.to_datetime(daily_counts['DATE_OF_INTEREST'])

daily_march = daily_counts[(daily_counts['DATE_OF_INTEREST'] > '02/29/2020') 
             & (daily_counts['DATE_OF_INTEREST'] < '04/01/2020')]

# %%
fig = px.line(daily_march, x='DATE_OF_INTEREST',y="CASE_COUNT",
             title='cases by day ')
fig.show()
# Out:
# <div>
#
#
#             <div id="14e10018-ff2d-4e53-bebc-b1febcd06d39" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("14e10018-ff2d-4e53-bebc-b1febcd06d39")) {
#                     Plotly.newPlot(
#                         '14e10018-ff2d-4e53-bebc-b1febcd06d39',
# ...

# %%
fig = px.line(daily_counts, x='DATE_OF_INTEREST',y="CASE_COUNT",
             title='cases by day ')
fig.show()
# Out:
# <div>
#
#
#             <div id="90a89360-fe79-4f4d-8c20-4d344ee2ab3f" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("90a89360-fe79-4f4d-8c20-4d344ee2ab3f")) {
#                     Plotly.newPlot(
#                         '90a89360-fe79-4f4d-8c20-4d344ee2ab3f',
# ...
